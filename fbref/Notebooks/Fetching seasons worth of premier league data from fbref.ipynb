# %% [markdown]
# In this notebook I'll look to fetch a seasons worth of premier league data.
#
# * Grab league table
# * Grab other tables (offensive, defensive data)
# * Grab fixtures

# %% [markdown]
# # Imports

# %%
import os
os.chdir("../")

# %%
import pandas as pd

from src.fbref.fbref_class import FBref

pd.set_option('display.max_columns', None)

# %% [markdown]
# # Config
#
# Setting out last season as out example season (prem 21/22)

# %%
season_name = "2021_2022"
league_id = 9
league_name = "Premier-League"

# %% [markdown]
# parameters if we were to grab La Liga's team data for last season (21/22)

# %%
# # additional example season
# season_name = "2021-2022"
# league_id = 12
# league_name = "La-Liga"

# %% [markdown]
# # Instantiate FBref class

# %%
fb = FBref()

# %% [markdown]
# # Fetch team data for example season
#
# Grab tables found on fbref for example season

# %%
league_team_dict = fb.get_fbref_league_team_data(season_name, league_id, league_name)

# %% [markdown]
# Show tables of data we have available
#
# NB: Any table with name ending in 'opp' indicates tables which contains opponent information. For example, 'shooting_opp' will contain information of the shotting stats of opppositions for each team in the league.

# %%
league_team_dict.keys()
# Out:
# dict_keys(['league_table', 'league_table_home_away', 'standard_stats', 'standard_stats_opp', 'goalkeeping', 'goalkeeping_opp', 'ad_goalkeeping', 'ad_goalkeeping_opp', 'shooting', 'shooting_opp', 'passing', 'passing_opp', 'pass_types', 'pass_types_opp', 'goal_shot_creation', 'goal_shot_creation_opp', 'defensive_action', 'defensive_action_opp', 'possession', 'possession_opp', 'playing_time', 'playing_time_opp', 'miscellaneous', 'miscellaneous_opp'])

# %% [markdown]
# Fetch dictionary of data for teams across example season. This dictionary will have data for league table, team data and corresponding data about opponents team faced.

# %%
team_data_dict = fb.get_team_data_dict(season_name, league_id, league_name, league_team_dict=None)

# %%
team_data_dict.keys()
# Out:
# dict_keys(['league_table', 'team_data', 'opponent_data'])

# %%
team_data_dict['team_data'].keys()
# Out:
# dict_keys(['attacking', 'defense', 'passing', 'goalkeeping', 'playing_time'])

# %%
team_data_dict['opponent_data'].keys()
# Out:
# dict_keys(['attacking', 'defense', 'passing', 'goalkeeping', 'playing_time'])

# %% [markdown]
# ### Grab league table data

# %%
team_data_dict['league_table'].head(3)
# Out:
#    Rk            Squad  MP   W   D  L  GF  GA  GD  Pts  Home_MP  Home_W  \
# 0   1  Manchester City  38  29   6  3  99  26  73   93       19      15
# 1   2        Liverpool  38  28   8  2  94  26  68   92       19      15
# 2   3          Chelsea  38  21  11  6  76  33  43   74       19       9
#
#    Home_D  Home_L  Home_GF  Home_GA  Home_GD  Home_Pts  Home_Pts/MP  Away_MP  \
# 0       2       2       58       15       43        47         2.47       19
# 1       4       0       49        9       40        49         2.58       19
# 2       7       3       37       22       15        34         1.79       19
#
#    Away_W  Away_D  Away_L  Away_GF  Away_GA  Away_GD  Away_Pts  Away_Pts/MP
# 0      14       4       1       41       11       30        46         2.42
# 1      13       4       2       45       17       28        43         2.26
# 2      12       4       3       39       11       28        40         2.11

# %% [markdown]
# ### Fetch team data

# %%
attacking_df = team_data_dict['team_data']['attacking']
defensive_df = team_data_dict['team_data']['defense']
passing_df = team_data_dict['team_data']['passing']
goalkeeping_df = team_data_dict['team_data']['goalkeeping']
playing_time_df = team_data_dict['team_data']['playing_time']

# %%
attacking_df.head(3)
# Out:
#          Squad  # Pl   Age  Poss  Playing Time_MP  Playing Time_Starts  \
# 0      Arsenal    27  24.4  52.8               38                  418
# 1  Aston Villa    31  26.1  46.5               38                  418
# 2    Brentford    29  25.4  44.8               38                  418
#
#    Playing Time_Min  Playing Time_90s  Performance_Gls  Performance_Ast  \
# 0              3420              38.0               60               41
# 1              3420              38.0               50               42
# 2              3420              38.0               46               33
#
#    Performance_G-PK  Performance_PK  Performance_PKatt  Performance_CrdY  \
# 0                55               5                  8                67
# 1                47               3                  3                81
# 2                40               6                  6                65
#
#    Performance_CrdR  Per 90 Minutes_Gls  Per 90 Minutes_Ast  \
# ...

# %% [markdown]
# ### Fetch opponent team data

# %%
attacking_opp_df = team_data_dict['opponent_data']['attacking']
defensive_opp_df = team_data_dict['opponent_data']['defense']
passing_opp_df = team_data_dict['opponent_data']['passing']
goalkeeping_opp_df = team_data_dict['opponent_data']['goalkeeping']
playing_time_opp_df = team_data_dict['opponent_data']['playing_time']

# %%
attacking_opp_df.head(3)
# Out:
#             Squad  # Pl   Age  Poss  Playing Time_MP  Playing Time_Starts  \
# 0      vs Arsenal    27  26.9  46.8               38                  418
# 1  vs Aston Villa    31  26.7  53.5               38                  418
# 2    vs Brentford    29  26.8  55.5               38                  418
#
#    Playing Time_Min  Playing Time_90s  Performance_Gls  Performance_Ast  \
# 0              3420              38.0               47               33
# 1              3420              38.0               52               35
# 2              3420              38.0               54               41
#
#    Performance_G-PK  Performance_PK  Performance_PKatt  Performance_CrdY  \
# 0                42               5                  6                69
# 1                48               4                  6                83
# 2                49               5                  5                50
#
#    Performance_CrdR  Per 90 Minutes_Gls  Per 90 Minutes_Ast  \
# ...

# %% [markdown]
# ### Grab fixtures for example league season

# %%
fixtures_df = fb.get_fbref_fixtures_and_results(season_name, league_id, league_name)
fixtures_df.head(3)
# Out:
# c:\Users\k2035549\OneDrive - King's College London\Desktop\python_projects\fbref\src\fbref\fbref_class.py:73: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   fixtures_df[["home_score", "away_score"]] = fixtures_df["Score"].str.split(
#     Wk  Day        Date   Time            Home   xG Score  xG.1          Away  \
# 0  1.0  Fri  2021-08-13  20:00       Brentford  1.6   2–0   1.6       Arsenal
# 1  1.0  Sat  2021-08-14  12:30  Manchester Utd  2.5   5–1   0.6  Leeds United
# 2  1.0  Sat  2021-08-14  15:00  Leicester City  0.7   1–0   1.5        Wolves
#
#    Attendance                        Venue         Referee  Match Report  \
# 0     16479.0  Brentford Community Stadium  Michael Oliver  Match Report
# 1     72732.0                 Old Trafford    Paul Tierney  Match Report
# 2     31983.0           King Power Stadium    Craig Pawson  Match Report
#
#    Notes home_score away_score
# ...
